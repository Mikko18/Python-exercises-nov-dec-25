# %%
number1 = 10
number2 = 20
if number1 == number2:
    print("number1 is equal to number2")
else:
    print("number1 is not equal to number2")
# Out:
# number1 is not equal to number2

# %%
number1 = 10
number2 = 20
if number1 > number2:
    print("number1 is greater than number2")
else:
    print("number1 is not greater than number2")
# Out:
# number1 is not greater than number2

# %%
number1 = 10
number2 = 20
if number1 >= number2:
    print("number1 is greater than or equal to number2")
else:
    print("number1 is less than number2")
# Out:
# number1 is less than number2

# %%
number1 = 10
number2 = 20
if number1 != number2:
    print("number1 is not equal to number2")
else:
    print("number1 is equal to number2")
# Out:
# number1 is not equal to number2

# %%
number1 = 10
number2 = 20
number3 = 30
if number1 == number2 == number3:
    print("All numbers are equal")
else:
    print("The numbers are not all equal")
# Out:
# The numbers are not all equal

# %%
number1 = 10
number2 = 20
number3 = 30
if number1 == number2 or number2 == number3:
    print("Either number1 and number2 are equal or number2 and number3 are equal")
else:
    print("Neither pair is equal")
# Out:
# Neither pair is equal

# %%
number1 = 10
number2 = 20
number3 = 30
if number1 > number2 and number1 > number3:
    print("number1 is greater than number2 and number3")
else:
    print("number1 is not greater than number2 and number3")
# Out:
# number1 is not greater than number2 and number3

# %%
number1 = 10
number2 = 20
number3 = 30
if number1 > number2:
    print("number1 is greater than number2")
else:
    if number2 > number3:
        print("number2 is greater than number3")
    else:
        print("number2 is not greater than number3")
# Out:
# number2 is not greater than number3

# %%
number1 = 10
number2 = 20
number3 = 30
if number1 == number2:
    print("number1 is equal to number2")
else:
    if number1 == number3:
        print("number1 is equal to number3")
    else:
        print("number1 is not equal to number2 or number3")
# Out:
# number1 is not equal to number2 or number3

# %%
name1 = "Austin"
name2 = "Ryan"
name3 = "Joey"
if name1 == name2:
    print("name1 and name2 are equal")
else:
    print("name1 and name2 are not equal")
# Out:
# name1 and name2 are not equal

# %%
name1 = "Nico"
name2 = "Gabriel"
if name1 != name2:
    print("name1 and name2 are not equal")
else:
    print("name1 and name2 are equal")
# Out:
# name1 and name2 are not equal

# %%
name1 = "Bubba"
name2 = "Riley"
name3 = "Tyler"
if name1 == name2:
    print("name1 and name2 are equal")
else:
    if name1 == name3:
        print("name1 and name3 are equal")
    else:
        print("name1 is not equal to name2 or name3")
# Out:
# name1 is not equal to name2 or name3
