# %%
print ("This app is made by:")
# Out:
# This app is made by:

# %%
creator = "Mikko"
print(creator)
# Out:
# Mikko

# %%
number1 = 67
number2 = 69

# %%
#comment print (number1)

# %%
print ("The value of number1 is 5")
# Out:
# The value of number1 is 5

# %%
print ("The value of number2 is 3")
# Out:
# The value of number2 is 3

# %%
multiplication = 4

# %%
print(f"Multiplication = {number1 * number2}")
# Out:
# Multiplication = 4623

# %%
sum = number1 + number2
print("Addition is:", sum)
# Out:
# Addition is: 136

# %%
sum = number1 / number2
print("Division is:", sum)
# Out:
# Division is: 0.9710144927536232

# %%
sum = number1 - number2
print("Substraction is"), sum
# Out:
# Substraction is
# (None, -2)
