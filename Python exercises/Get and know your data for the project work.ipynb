# %%
import pandas as pd

# %%
# Import the necessary libraries
import pandas as pd

# Import the dataset from this url https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv
# Assign the url to a variable called url and create a dataframe named chipo.
url = 'comments.csv'
Dataset = pd.read_csv(url)

# %%
Dataset.head(10)
# Out:
#    id                    comment_text  user_id  photo_id           created_at
# 0   1                 unde at dolorem        2         1  2023-05-13 15:14:58
# 1   2                 quae ea ducimus        3         1  2023-05-13 15:14:58
# 2   3              alias a voluptatum        5         1  2023-05-13 15:14:58
# 3   4            facere suscipit sunt       14         1  2023-05-13 15:14:58
# 4   5          totam eligendi quaerat       17         1  2023-05-13 15:14:58
# 5   6              vitae quia aliquam       21         1  2023-05-13 15:14:58
# 6   7  exercitationem occaecati neque       24         1  2023-05-13 15:14:58
# 7   8                  sint ad fugiat       31         1  2023-05-13 15:14:58
# 8   9           nesciunt aut nesciunt       36         1  2023-05-13 15:14:58
# 9  10           laudantium ut nostrum       41         1  2023-05-13 15:14:58

# %%
Dataset.shape[0]
# Out:
# 1000

# %%
Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1000 non-null   int64
#  1   comment_text  1000 non-null   object
#  2   user_id       1000 non-null   int64
#  3   photo_id      1000 non-null   int64
#  4   created_at    1000 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %%
Dataset.shape
# Out:
# (1000, 5)

# %%
Dataset.shape[1]
# Out:
# 5

# %%
Dataset.columns
# Out:
# Index(['id', 'comment_text', 'user_id', 'photo_id', 'created_at'], dtype='object')

# %%
Dataset.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
Dataset.values
# Out:
# array([[1, 'unde at dolorem', 2, 1, '2023-05-13 15:14:58'],
#        [2, 'quae ea ducimus', 3, 1, '2023-05-13 15:14:58'],
#        [3, 'alias a voluptatum', 5, 1, '2023-05-13 15:14:58'],
#        ...,
#        [998, 'dolorem dolor sed', 30, 35, '2023-05-13 15:14:58'],
#        [999, 'dicta aut non', 32, 35, '2023-05-13 15:14:58'],
#        [1000, 'mollitia et praesentium', 36, 35, '2023-05-13 15:14:58']],
#       shape=(1000, 5), dtype=object)

# %%
column_data_type = Dataset['photo_id'].dtype
print(column_data_type)
# Out:
# int64

# %%
Dataset.sort_values("photo_id")
# Out:
#        id             comment_text  user_id  photo_id           created_at
# 0       1          unde at dolorem        2         1  2023-05-13 15:14:58
# 1       2          quae ea ducimus        3         1  2023-05-13 15:14:58
# 2       3       alias a voluptatum        5         1  2023-05-13 15:14:58
# 3       4     facere suscipit sunt       14         1  2023-05-13 15:14:58
# 4       5   totam eligendi quaerat       17         1  2023-05-13 15:14:58
# ..    ...                      ...      ...       ...                  ...
# 995   996     recusandae magnam ut       24        35  2023-05-13 15:14:58
# 996   997  incidunt qui blanditiis       27        35  2023-05-13 15:14:58
# 997   998        dolorem dolor sed       30        35  2023-05-13 15:14:58
# 998   999            dicta aut non       32        35  2023-05-13 15:14:58
# 999  1000  mollitia et praesentium       36        35  2023-05-13 15:14:58
#
# [1000 rows x 5 columns]

# %%
Dataset.sort_values("photo_id", ascending=False)
# Out:
#        id             comment_text  user_id  photo_id           created_at
# 999  1000  mollitia et praesentium       36        35  2023-05-13 15:14:58
# 997   998        dolorem dolor sed       30        35  2023-05-13 15:14:58
# 998   999            dicta aut non       32        35  2023-05-13 15:14:58
# 996   997  incidunt qui blanditiis       27        35  2023-05-13 15:14:58
# 991   992       nisi eaque dolores       15        35  2023-05-13 15:14:58
# ..    ...                      ...      ...       ...                  ...
# 4       5   totam eligendi quaerat       17         1  2023-05-13 15:14:58
# 3       4     facere suscipit sunt       14         1  2023-05-13 15:14:58
# 2       3       alias a voluptatum        5         1  2023-05-13 15:14:58
# 1       2          quae ea ducimus        3         1  2023-05-13 15:14:58
# 0       1          unde at dolorem        2         1  2023-05-13 15:14:58
#
# [1000 rows x 5 columns]

# %%
Dataset.sort_values(["photo_id", "user_id"])
# Out:
#        id             comment_text  user_id  photo_id           created_at
# 0       1          unde at dolorem        2         1  2023-05-13 15:14:58
# 1       2          quae ea ducimus        3         1  2023-05-13 15:14:58
# 2       3       alias a voluptatum        5         1  2023-05-13 15:14:58
# 3       4     facere suscipit sunt       14         1  2023-05-13 15:14:58
# 4       5   totam eligendi quaerat       17         1  2023-05-13 15:14:58
# ..    ...                      ...      ...       ...                  ...
# 995   996     recusandae magnam ut       24        35  2023-05-13 15:14:58
# 996   997  incidunt qui blanditiis       27        35  2023-05-13 15:14:58
# 997   998        dolorem dolor sed       30        35  2023-05-13 15:14:58
# 998   999            dicta aut non       32        35  2023-05-13 15:14:58
# 999  1000  mollitia et praesentium       36        35  2023-05-13 15:14:58
#
# [1000 rows x 5 columns]

# %%
Dataset.sort_values(["photo_id", "comment_text"], ascending=[True, False])
# Out:
#       id                comment_text  user_id  photo_id           created_at
# 23    24           voluptatum sit id       91         1  2023-05-13 15:14:58
# 17    18    voluptas nemo blanditiis       71         1  2023-05-13 15:14:58
# 5      6          vitae quia aliquam       21         1  2023-05-13 15:14:58
# 0      1             unde at dolorem        2         1  2023-05-13 15:14:58
# 4      5      totam eligendi quaerat       17         1  2023-05-13 15:14:58
# ..   ...                         ...      ...       ...                  ...
# 992  993          est ullam suscipit       16        35  2023-05-13 15:14:58
# 997  998           dolorem dolor sed       30        35  2023-05-13 15:14:58
# 998  999               dicta aut non       32        35  2023-05-13 15:14:58
# 990  991  consequuntur aut veritatis       14        35  2023-05-13 15:14:58
# 993  994         aliquid sapiente ut       19        35  2023-05-13 15:14:58
#
# [1000 rows x 5 columns]

# %%
subset_Dataset = Dataset["photo_id"]
print(subset_Dataset)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 995    35
# 996    35
# 997    35
# 998    35
# 999    35
# Name: photo_id, Length: 1000, dtype: int64

# %%
subset_Dataset1 = Dataset[["photo_id", "user_id", "comment_text"]]
print(subset_Dataset1)
# Out:
#      photo_id  user_id             comment_text
# 0           1        2          unde at dolorem
# 1           1        3          quae ea ducimus
# 2           1        5       alias a voluptatum
# 3           1       14     facere suscipit sunt
# 4           1       17   totam eligendi quaerat
# ..        ...      ...                      ...
# 995        35       24     recusandae magnam ut
# 996        35       27  incidunt qui blanditiis
# 997        35       30        dolorem dolor sed
# 998        35       32            dicta aut non
# 999        35       36  mollitia et praesentium
#
# [1000 rows x 3 columns]

# %%
import pandas as pd

# %%
# Import the necessary libraries
import pandas as pd

# Import the dataset from this url https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv
# Assign the url to a variable called url and create a dataframe named chipo.
url = 'comments.csv'
Dataset = pd.read_csv(url)

# %%
print(Dataset['comment_text'].dtype)
# Out:
# object

# %%
Dataset['photo_id'] = Dataset['user_id'] * Dataset['comment_text']

# %%
Dataset.head(20)
# Out:
#     id                      comment_text  user_id  \
# 0    1                   unde at dolorem        2
# 1    2                   quae ea ducimus        3
# 2    3                alias a voluptatum        5
# 3    4              facere suscipit sunt       14
# 4    5            totam eligendi quaerat       17
# 5    6                vitae quia aliquam       21
# 6    7    exercitationem occaecati neque       24
# 7    8                    sint ad fugiat       31
# 8    9             nesciunt aut nesciunt       36
# 9   10             laudantium ut nostrum       41
# 10  11              omnis aut asperiores       52
# 11  12                  et eum molestias       54
# 12  13              alias pariatur neque       55
# 13  14                amet iure adipisci       57
# 14  15                 cum enim repellat       62
# 15  16             provident dolorem non       63
# 16  17          eos consequuntur impedit       66
# 17  18          voluptas nemo blanditiis       71
# ...

# %%
def categorize_user(user_id):
    if user_id < 20:
        return 'Low'
    elif user_id < 50:
        return 'Medium'
    else:
        return 'High'
