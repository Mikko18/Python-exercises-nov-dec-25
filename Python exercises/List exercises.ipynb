# %%
furniture = ["table", "chair", "shelf"]
print(", ".join(furniture))
# Out:
# table, chair, shelf

# %%
furniture = ["table", "chair"]
print(", ".join(furniture))
# Out:
# table, chair

# %%
furniture = ["table", "chair"]
for item in furniture:
    if item.lower() == "sofa":
        print("sofa")

# %%
thrownDiceNumbers = [3, 4, 3, 5, 2]
total = sum(thrownDiceNumbers)
print("total:", total)
# Out:
# total: 17

# %%
print("highest value:", max(thrownDiceNumbers))
# Out:
# highest value: 5
